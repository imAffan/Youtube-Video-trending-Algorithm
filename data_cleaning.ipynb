# %% [markdown]
# ### Importing Dependencies

# %%
import pandas as pd
import os
import requests
import json
# from config import password
from sqlalchemy import create_engine

# %% [markdown]
# ### Creating a function to import csv data from multiple countries

# %%
# def import_func(country_code):
    
#     #Creating Path
#     cd  = 'D:\MyProjects\Clones\YTP\data\\newData'
#     country = country_code
#     cd+='\\'
#     cd+=country_code
#     cd+='_youtube_trending_data.csv'
#     #path = cd.join(f'{country_code}_youtube_trending_data.csv')
#     path = cd
    
#     #Storing dataframe to df
#     print(path)
#     df=pd.read_csv(path)
    
#     #Removing unwanted columns below
    
#     df=df[['video_id','title','publishedAt','channelTitle','categoryId','trending_date',
#             'view_count','likes','dislikes','comment_count','thumbnail_link']]
    
    
#     #Changing object types to date types for two columns
    
#     df['publishedAt']=pd.to_datetime(df['publishedAt'])
#     df['trending_date']=pd.to_datetime(df['trending_date'])
    
    
#     #Removing time stamp from date
    
#     df['publishedAt']=df['publishedAt'].dt.date 
#     df['trending_date']=df['trending_date'].dt.date
    
#     jsoncwd = 'data\\newData\\' + country_code + '_category_id.json'
#     #with open(f'data/{country_code}_category_id.json', 'r') as read_file:
#     with open(jsoncwd, 'r') as read_file:
#         category_ids = json.load(read_file)

#         df=df.astype({'categoryId': 'str'})
        
#     for index,row in df.iterrows():
    
#         for entry in category_ids["items"]:

#             if row["categoryId"]==entry["id"]:
#                 df.at[index,"categoryId"]=entry["snippet"]["title"]
    
#     #Adding country Code as column
#     df['country']=f'{country_code}'
#     col_name='country'
    
    
#     #Moving country code to first column
#     first_col = df.pop(col_name)
#     df.insert(0,col_name,first_col)
    
#     return df

# cwd = 'D:\MyProjects\Clones\YTP\data\\newData'
# print(os.getcwd())
# Out:
# d:\MyProjects\Clones\YTP

# %% [markdown]
# ### Creating all dataframes using import function

# %%
# #USA Dataframe
# df_us=import_func('US')

# #Brasil Dataframe
# df_br=import_func('BR')

# #Canada Dataframe
# df_ca=import_func('CA')

# #Mexico Dataframe
# df_mx=import_func('MX')
# Out:
# D:\MyProjects\Clones\YTP\data\newData\US_youtube_trending_data.csv
# D:\MyProjects\Clones\YTP\data\newData\BR_youtube_trending_data.csv
# D:\MyProjects\Clones\YTP\data\newData\CA_youtube_trending_data.csv
# D:\MyProjects\Clones\YTP\data\newData\MX_youtube_trending_data.csv

# %% [markdown]
# ### Combining all data to one dataframe

# %%
# #Creating a varible to add all dfs
# country_df=[df_us,df_br,df_ca,df_mx]

# df_main = pd.concat(country_df)
# df_main
# Out:
#       country     video_id                                              title  \
# 0          US  3C66w5Z0ixs                 I ASKED HER TO BE MY GIRLFRIEND...
# 1          US  M9Pmf9AB4Mo  Apex Legends | Stories from the Outlands – “Th...
# 2          US  J78aPJ3VyNs  I left youtube for a month and THIS is what ha...
# 3          US  kXLn3HkpjaA  XXL 2020 Freshman Class Revealed - Official An...
# 4          US  VIUo6yapDbc  Ultimate DIY Home Movie Theater for The LaBran...
# ...       ...          ...                                                ...
# 46794      MX  2GyH_-SyK5A     NERFEAR A CR7 EN LA ACTUALIZACIÓN DE FREE FIRE
# 46795      MX  X5Xl2S9yBgM  BROMA MUY PESADA A MANUEL RIVERA *CHOQUE SU ME...
# 46796      MX  3EW6Zk1BgX0  AURONPLAY Y GREFG POR PRIMERA VEZ JUGANDO FORT...
# 46797      MX  rIPkkoJoG2s                      ASTRO 아스트로 - ONE M/V TEASER 1
# 46798      MX  VXfY0qClBoI  Padres vs. D-backs Game Highlights (4/1/21) | ...
#
#       publishedAt    channelTitle        categoryId trending_date  view_count  \
# 0      2020-08-11        Brawadis    People & Blogs    2020-08-12     1514614
# 1      2020-08-11    Apex Legends            Gaming    2020-08-12     2381688
# 2      2020-08-11   jacksepticeye     Entertainment    2020-08-12     2038853
# 3      2020-08-11             XXL             Music    2020-08-12      496771
# 4      2020-08-11        Mr. Kate     Howto & Style    2020-08-12     1123889
# ...           ...             ...               ...           ...         ...
# 46794  2021-03-31      Memounstro            Gaming    2021-04-07      283292
# 46795  2021-03-30  Alberto Orozco  Autos & Vehicles    2021-04-07      259087
# 46796  2021-03-30        TheGrefg            Gaming    2021-04-07     3300261
# 46797  2021-03-30   fantagio 판타지오     Entertainment    2021-04-07      483548
# 46798  2021-04-02             MLB            Sports    2021-04-07      417420
#
#         likes  dislikes  comment_count  \
# 0      156908      5855          35313
# 1      146739      2794          16549
# 2      353787      2628          40221
# 3       23251      1856           7647
# 4       45802       964           2196
# ...       ...       ...            ...
# 46794   42386       985           4290
# 46795   16128       541            476
# 46796  279884      3214           5760
# 46797   79614       181           7439
# 46798    3728       122            334
#
#                                        thumbnail_link
# 0      https://i.ytimg.com/vi/3C66w5Z0ixs/default.jpg
# 1      https://i.ytimg.com/vi/M9Pmf9AB4Mo/default.jpg
# 2      https://i.ytimg.com/vi/J78aPJ3VyNs/default.jpg
# 3      https://i.ytimg.com/vi/kXLn3HkpjaA/default.jpg
# 4      https://i.ytimg.com/vi/VIUo6yapDbc/default.jpg
# ...                                               ...
# 46794  https://i.ytimg.com/vi/2GyH_-SyK5A/default.jpg
# 46795  https://i.ytimg.com/vi/X5Xl2S9yBgM/default.jpg
# 46796  https://i.ytimg.com/vi/3EW6Zk1BgX0/default.jpg
# 46797  https://i.ytimg.com/vi/rIPkkoJoG2s/default.jpg
# 46798  https://i.ytimg.com/vi/VXfY0qClBoI/default.jpg
#
# [187727 rows x 12 columns]

# %% [markdown]
# ### ADDED TODAY

# %% [markdown]
# ### Creating a function to get popular statistics

# %%
# def stats(country_code):
    
#     #Invoiking import_func to capture all the date based on country

#     df=import_func(f'{country_code}')
    

#     #Grouping dataframe by category to get all likes
    
#     df_likes=df.groupby('categoryId').likes.sum()
    
    
#     #Grouping dataframe by category to get all dislikes
    
#     df_dislikes=df.groupby('categoryId').dislikes.sum()
    
    
#     ##Grouping dataframe by category to get total view count
    
#     df_view_count=df.groupby('categoryId').view_count.sum()
   
   
#     return df_likes.reset_index(),df_dislikes.reset_index(),df_view_count.reset_index()

# %%
#Example


# df_US_likes,df_US_dislikes,df_US_view_count=stats('US')
# Out:
# D:\MyProjects\Clones\YTP\data\newData\US_youtube_trending_data.csv

# %% [markdown]
# ### Creating SQL engine to connnect to Postgres

# %%
# # #Connect to Database

pg_user = 'postgres'
pg_password='Sm6Jc5bqbiNQdsVAo7eN'
db_name = 'YTP_database'
connection_string = f'{pg_user}:{pg_password}@localhost:5432/{db_name}'
engine=create_engine(f'postgresql://{connection_string}')

# #Connect to Database - Alternative
# dbuser = 'postgres'
# dbpassword = 'Sm6Jc5bqbiNQdsVAo7eN'
# dbhost = 'localhost'
# dbport = '5432'
# dbname= 'youtube_database'
# connection_string2 = f'{dbuser}:{dbpassword}@database-1.cvmfiiilpm7y.us-east-1.rds.amazonaws.com:{dbport}/{dbname}'
# engine=create_engine(f'postgresql://{connection_string2}')

# %%
# engine.table_names()

# %%
# df_main.to_sql(name='youtube_table',con=engine,if_exists='append',index=False)

# %% [markdown]
# #### For App.py routes

# %%
# from datetime import datetime

# # Routes to fill the drop down menus
# # Dropdown menu#1
# youtubeVids = df_main
# country_df = youtubeVids['country'].value_counts() 
# countryList = country_df.index.tolist()
# countryList

# # Dropdown menu#2
# youtubeVids = df_main
# youtubeVids['categoryId'] = youtubeVids['categoryId'].replace(["29"],"Nonprofits & Activism")
# category_df = df_main['categoryId'].value_counts() 
# categoryList = category_df.index.tolist()
# categoryList

# # Dropdown menu#3
# metricList = ['Views', 'Likes', 'Dislikes', 'Comments']

# %%
# df_main = df_main.rename(columns={'country': 'country', 'video_id': 'video_id', 'title': 'title', 'publishedAt': 'publishedAt', 'channelTitle': 'channelTitle', 'categoryId': 'categoryId',
#                                   'trending_date': 'trending_date', 'view_count': 'views', 'likes': 'likes', 'dislikes': 'dislikes', 'comment_count': 'comments', 'thumbnail_link': 'thumbnail_link'})

# %%
# CREATING A HEROKU DATASET
# Heroku only takes data with <10k rows so I created a heroku dataset (incase we ever want to host on heroku).

def import_func(country_code):
    
    #Creating Path
    path = os.path.join('data\\newData',f'{country_code}_youtube_trending_data.csv')
    
    
    #Storing dataframe to df
    dfh=pd.read_csv(path)
    
    #Removing unwanted columns below
    dfh=dfh[['video_id','title','publishedAt','channelTitle','categoryId','trending_date','view_count','likes','dislikes','comment_count','thumbnail_link']]
    
    #Renaming columns
    dfh = dfh.rename(columns={'view_count': 'views', 'likes': 'likes', 'dislikes': 'dislikes', 'comment_count': 'comments'})
    
    #Changing object types to date types for two columns
    dfh['publishedAt']=pd.to_datetime(dfh['publishedAt'])
    dfh['trending_date']=pd.to_datetime(dfh['trending_date'])
    
    
    #Removing time stamp from date
    dfh['publishedAt']=dfh['publishedAt'].dt.date 
    dfh['trending_date']=dfh['trending_date'].dt.date
    
    
    with open(f'data/newData/{country_code}_category_id.json', 'r') as read_file:
        category_ids = json.load(read_file)

        dfh=dfh.astype({'categoryId': 'str'})
        
    for index,row in dfh.iterrows():
    
        for entry in category_ids["items"]:

            if row["categoryId"]==entry["id"]:
                dfh.at[index,"categoryId"]=entry["snippet"]["title"]
    
    # Select 999 rows from each country in dataframe (so we end up with <10k rows ~1000 rows per country)
    dfh = dfh.nlargest(999, 'views')
    
    #Adding country Code as column
    dfh['country']=f'{country_code}'
    col_name='country'
    
    #Moving country code to first column
    first_col = dfh.pop(col_name)
    dfh.insert(0,col_name,first_col)
    
    return dfh

#USA Dataframe
dfh_us=import_func('US')

#Brasil Dataframe
dfh_br=import_func('BR')

#Canada Dataframe
dfh_ca=import_func('CA')

#Mexico Dataframe
dfh_mx=import_func('MX')

#GB Dataframe
dfh_gb=import_func('GB')

#France Dataframe
dfh_fr=import_func('FR')

#Russia Dataframe
dfh_ru=import_func('RU')

#Japan Dataframe
dfh_jp=import_func('JP')

#Korea Dataframe
dfh_kr=import_func('KR')

#India Dataframe
dfh_in=import_func('IN')


#Creating a varible to add all dfs
country_dfh=[dfh_us, dfh_br, dfh_ca, dfh_mx, dfh_gb, dfh_fr, dfh_ru ,dfh_jp, dfh_kr ,dfh_in]

dfh_main = pd.concat(country_dfh)
dfh_main

# Fix the 29 vs Non profits issue
dfh_main['categoryId'] = dfh_main['categoryId'].replace(["29"],"Nonprofits & Activism")

#View output
dfh_main


# To upload to postgres SQL db
# You first have to go create the db (named youtube_table2) in postgres

# #Connect to Database
pg_user = 'postgres'
pg_password='Sm6Jc5bqbiNQdsVAo7eN'
db_name = 'youtube_database'
connection_string = f'{pg_user}:{pg_password}@localhost:5432/{db_name}'
engine=create_engine(f'postgresql://{connection_string}')

#Connect to Database - Alternative

# dbuser = 'postgres'
# dbpassword = 'Sm6Jc5bqbiNQdsVAo7eN'
# dbhost = 'localhost'
# dbport = '5432'
# dbname= 'youtube_database'
# connection_string2 = f'{dbuser}:{dbpassword}@database-1.cvmfiiilpm7y.us-east-1.rds.amazonaws.com:{dbport}/{dbname}'
# engine=create_engine(f'postgresql://{connection_string2}')

# Upload to postgres
print(dfh_main)
dfh_main.to_sql(name='youtube_table2',con=engine,if_exists='append',index=False)
# Out:
# ---------------------------------------------------------------------------
# UndefinedColumn                           Traceback (most recent call last)
# File d:\MyProjects\Clones\YTP\env\lib\site-packages\sqlalchemy\engine\base.py:1685, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1684     if not evt_handled:
# -> 1685         self.dialect.do_executemany(
#    1686             cursor, statement, parameters, context
#    1687         )
#    1688 elif not parameters and context.no_parameters:
#
# File d:\MyProjects\Clones\YTP\env\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py:903, in PGDialect_psycopg2.do_executemany(self, cursor, statement, parameters, context)
#     902     xtras = self._psycopg2_extras()
# --> 903     context._psycopg2_fetched_rows = xtras.execute_values(
#     904         cursor,
#     905         statement,
#     906         parameters,
#     907         template=executemany_values,
#     908         fetch=bool(context.compiled.returning),
#     909         **kwargs
#     910     )
#     912 elif self.executemany_mode & EXECUTEMANY_BATCH:
#
# File d:\MyProjects\Clones\YTP\env\lib\site-packages\psycopg2\extras.py:1292, in execute_values(cur, sql, argslist, template, page_size, fetch)
#    1291 parts[-1:] = post
# -> 1292 cur.execute(b''.join(parts))
#    1293 if fetch:
#
# UndefinedColumn: column "country" of relation "youtube_table2" does not exist
# LINE 1: INSERT INTO youtube_table2 (country, video_id, title, "publi...
#                                     ^
#
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# Cell In [11], line 119
#     106 engine=create_engine(f'postgresql://{connection_string}')
#     108 #Connect to Database - Alternative
#     109
#     110 # dbuser = 'postgres'
#    (...)
#     117
#     118 # Upload to postgres
# --> 119 dfh_main.to_sql(name='youtube_table2',con=engine,if_exists='append',index=False)
#
# File d:\MyProjects\Clones\YTP\env\lib\site-packages\pandas\core\generic.py:2779, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2637 """
#    2638 Write records stored in a DataFrame to a SQL database.
#    2639
#    (...)
#    2775 [(1,), (None,), (2,)]
#    2776 """
#    2777 from pandas.io import sql
# -> 2779 sql.to_sql(
#    2780     self,
#    2781     name,
#    2782     con,
#    2783     schema=schema,
#    2784     if_exists=if_exists,
#    2785     index=index,
#    2786     index_label=index_label,
#    2787     chunksize=chunksize,
#    2788     dtype=dtype,
#    2789     method=method,
#    2790 )
#
# File d:\MyProjects\Clones\YTP\env\lib\site-packages\pandas\io\sql.py:590, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     585 elif not isinstance(frame, DataFrame):
#     586     raise NotImplementedError(
#     587         "'frame' argument should be either a Series or a DataFrame"
#     588     )
# --> 590 pandas_sql.to_sql(
#     591     frame,
#     592     name,
#     593     if_exists=if_exists,
#     594     index=index,
#     595     index_label=index_label,
#     596     schema=schema,
#     597     chunksize=chunksize,
#     598     dtype=dtype,
#     599     method=method,
#     600 )
#
# File d:\MyProjects\Clones\YTP\env\lib\site-packages\pandas\io\sql.py:1405, in SQLDatabase.to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1403         raise ValueError("inf cannot be used with MySQL") from err
#    1404     else:
# -> 1405         raise err
#    1407 if not name.isdigit() and not name.islower():
#    1408     # check for potentially case sensitivity issues (GH7815)
#    1409     # Only check when name is not a number and name is not lower case
#    1410     engine = self.connectable.engine
#
# File d:\MyProjects\Clones\YTP\env\lib\site-packages\pandas\io\sql.py:1397, in SQLDatabase.to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1394 from sqlalchemy import exc
#    1396 try:
# -> 1397     table.insert(chunksize, method=method)
#    1398 except exc.SQLAlchemyError as err:
#    1399     # GH34431
#    1400     msg = "(1054, \"Unknown column 'inf' in 'field list'\")"
#
# File d:\MyProjects\Clones\YTP\env\lib\site-packages\pandas\io\sql.py:831, in SQLTable.insert(self, chunksize, method)
#     828     break
#     830 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 831 exec_insert(conn, keys, chunk_iter)
#
# File d:\MyProjects\Clones\YTP\env\lib\site-packages\pandas\io\sql.py:748, in SQLTable._execute_insert(self, conn, keys, data_iter)
#     736 """
#     737 Execute SQL statement inserting data
#     738
#    (...)
#     745    Each item contains a list of values to be inserted
#     746 """
#     747 data = [dict(zip(keys, row)) for row in data_iter]
# --> 748 conn.execute(self.table.insert(), data)
#
# File d:\MyProjects\Clones\YTP\env\lib\site-packages\sqlalchemy\engine\base.py:1200, in Connection.execute(self, statement, *multiparams, **params)
#    1196     util.raise_(
#    1197         exc.ObjectNotExecutableError(statement), replace_context=err
#    1198     )
#    1199 else:
# -> 1200     return meth(self, multiparams, params, _EMPTY_EXECUTION_OPTS)
#
# File d:\MyProjects\Clones\YTP\env\lib\site-packages\sqlalchemy\sql\elements.py:313, in ClauseElement._execute_on_connection(self, connection, multiparams, params, execution_options, _force)
#     309 def _execute_on_connection(
#     310     self, connection, multiparams, params, execution_options, _force=False
#     311 ):
#     312     if _force or self.supports_execution:
# --> 313         return connection._execute_clauseelement(
#     314             self, multiparams, params, execution_options
#     315         )
#     316     else:
#     317         raise exc.ObjectNotExecutableError(self)
#
# File d:\MyProjects\Clones\YTP\env\lib\site-packages\sqlalchemy\engine\base.py:1389, in Connection._execute_clauseelement(self, elem, multiparams, params, execution_options)
#    1377 compiled_cache = execution_options.get(
#    1378     "compiled_cache", self.engine._compiled_cache
#    1379 )
#    1381 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1382     dialect=dialect,
#    1383     compiled_cache=compiled_cache,
#    (...)
#    1387     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1388 )
# -> 1389 ret = self._execute_context(
#    1390     dialect,
#    1391     dialect.execution_ctx_cls._init_compiled,
#    1392     compiled_sql,
#    1393     distilled_params,
#    1394     execution_options,
#    1395     compiled_sql,
#    1396     distilled_params,
#    1397     elem,
#    1398     extracted_params,
#    1399     cache_hit=cache_hit,
#    1400 )
#    1401 if has_events:
#    1402     self.dispatch.after_execute(
#    1403         self,
#    1404         elem,
#    (...)
#    1408         ret,
#    1409     )
#
# File d:\MyProjects\Clones\YTP\env\lib\site-packages\sqlalchemy\engine\base.py:1748, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1745             branched.close()
#    1747 except BaseException as e:
# -> 1748     self._handle_dbapi_exception(
#    1749         e, statement, parameters, cursor, context
#    1750     )
#    1752 return result
#
# File d:\MyProjects\Clones\YTP\env\lib\site-packages\sqlalchemy\engine\base.py:1929, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1927     util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    1928 elif should_wrap:
# -> 1929     util.raise_(
#    1930         sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1931     )
#    1932 else:
#    1933     util.raise_(exc_info[1], with_traceback=exc_info[2])
#
# File d:\MyProjects\Clones\YTP\env\lib\site-packages\sqlalchemy\util\compat.py:211, in raise_(***failed resolving arguments***)
#     208     exception.__cause__ = replace_context
#     210 try:
# --> 211     raise exception
#     212 finally:
#     213     # credit to
#     214     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     215     # as the __traceback__ object creates a cycle
#     216     del exception, replace_context, from_, with_traceback
#
# File d:\MyProjects\Clones\YTP\env\lib\site-packages\sqlalchemy\engine\base.py:1685, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1683                 break
#    1684     if not evt_handled:
# -> 1685         self.dialect.do_executemany(
#    1686             cursor, statement, parameters, context
#    1687         )
#    1688 elif not parameters and context.no_parameters:
#    1689     if self.dialect._has_events:
#
# File d:\MyProjects\Clones\YTP\env\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py:903, in PGDialect_psycopg2.do_executemany(self, cursor, statement, parameters, context)
#     901         kwargs = {}
#     902     xtras = self._psycopg2_extras()
# --> 903     context._psycopg2_fetched_rows = xtras.execute_values(
#     904         cursor,
#     905         statement,
#     906         parameters,
#     907         template=executemany_values,
#     908         fetch=bool(context.compiled.returning),
#     909         **kwargs
#     910     )
#     912 elif self.executemany_mode & EXECUTEMANY_BATCH:
#     913     if self.executemany_batch_page_size:
#
# File d:\MyProjects\Clones\YTP\env\lib\site-packages\psycopg2\extras.py:1292, in execute_values(cur, sql, argslist, template, page_size, fetch)
#    1290     parts.append(b',')
#    1291 parts[-1:] = post
# -> 1292 cur.execute(b''.join(parts))
#    1293 if fetch:
#    1294     result.extend(cur.fetchall())
#
# ProgrammingError: (psycopg2.errors.UndefinedColumn) column "country" of relation "youtube_table2" does not exist
# LINE 1: INSERT INTO youtube_table2 (country, video_id, title, "publi...
#                                     ^
#
# [SQL: INSERT INTO youtube_table2 (country, video_id, title, "publishedAt", "channelTitle", "categoryId", trending_date, views, likes, dislikes, comments, thumbnail_link) VALUES (%(country)s, %(video_id)s, %(title)s, %(publishedAt)s, %(channelTitle)s, %(categoryId)s, %(trending_date)s, %(views)s, %(likes)s, %(dislikes)s, %(comments)s, %(thumbnail_link)s)]
# [parameters: ({'country': 'US', 'video_id': 'gdZLi9oWNZg', 'title': "BTS (방탄소년단) 'Dynamite' Official MV", 'publishedAt': datetime.date(2020, 8, 21), 'channelTitle': 'Big Hit Labels', 'categoryId': 'Music', 'trending_date': datetime.date(2020, 8, 28), 'views': 232649205, 'likes': 15735533, 'dislikes': 714194, 'comments': 6065230, 'thumbnail_link': 'https://i.ytimg.com/vi/gdZLi9oWNZg/default.jpg'}, {'country': 'US', 'video_id': 'gdZLi9oWNZg', 'title': "BTS (방탄소년단) 'Dynamite' Official MV", 'publishedAt': datetime.date(2020, 8, 21), 'channelTitle': 'Big Hit Labels', 'categoryId': 'Music', 'trending_date': datetime.date(2020, 8, 27), 'views': 219110491, 'likes': 15460822, 'dislikes': 674291, 'comments': 5810680, 'thumbnail_link': 'https://i.ytimg.com/vi/gdZLi9oWNZg/default.jpg'}, {'country': 'US', 'video_id': 'gdZLi9oWNZg', 'title': "BTS (방탄소년단) 'Dynamite' Official MV", 'publishedAt': datetime.date(2020, 8, 21), 'channelTitle': 'Big Hit Labels', 'categoryId': 'Music', 'trending_date': datetime.date(2020, 8, 26), 'views': 208581468, 'likes': 15246496, 'dislikes': 646349, 'comments': 5744496, 'thumbnail_link': 'https://i.ytimg.com/vi/gdZLi9oWNZg/default.jpg'}, {'country': 'US', 'video_id': 'gdZLi9oWNZg', 'title': "BTS (방탄소년단) 'Dynamite' Official MV", 'publishedAt': datetime.date(2020, 8, 21), 'channelTitle': 'Big Hit Labels', 'categoryId': 'Music', 'trending_date': datetime.date(2020, 8, 25), 'views': 200692965, 'likes': 14994034, 'dislikes': 621578, 'comments': 5623570, 'thumbnail_link': 'https://i.ytimg.com/vi/gdZLi9oWNZg/default.jpg'}, {'country': 'US', 'video_id': 'vRXZj0DzXIA', 'title': "BLACKPINK - 'Ice Cream (with Selena Gomez)' M/V", 'publishedAt': datetime.date(2020, 8, 28), 'channelTitle': 'BLACKPINK', 'categoryId': 'Music', 'trending_date': datetime.date(2020, 9, 5), 'views': 184778248, 'likes': 11795670, 'dislikes': 879354, 'comments': 2735997, 'thumbnail_link': 'https://i.ytimg.com/vi/vRXZj0DzXIA/default.jpg'}, {'country': 'US', 'video_id': 'gdZLi9oWNZg', 'title': "BTS (방탄소년단) 'Dynamite' Official MV", 'publishedAt': datetime.date(2020, 8, 21), 'channelTitle': 'Big Hit Labels', 'categoryId': 'Music', 'trending_date': datetime.date(2020, 8, 24), 'views': 183414472, 'likes': 14678048, 'dislikes': 576852, 'comments': 5748638, 'thumbnail_link': 'https://i.ytimg.com/vi/gdZLi9oWNZg/default.jpg'}, {'country': 'US', 'video_id': 'vRXZj0DzXIA', 'title': "BLACKPINK - 'Ice Cream (with Selena Gomez)' M/V", 'publishedAt': datetime.date(2020, 8, 28), 'channelTitle': 'BLACKPINK', 'categoryId': 'Music', 'trending_date': datetime.date(2020, 9, 4), 'views': 176467113, 'likes': 11645386, 'dislikes': 865074, 'comments': 2722454, 'thumbnail_link': 'https://i.ytimg.com/vi/vRXZj0DzXIA/default.jpg'}, {'country': 'US', 'video_id': 'vRXZj0DzXIA', 'title': "BLACKPINK - 'Ice Cream (with Selena Gomez)' M/V", 'publishedAt': datetime.date(2020, 8, 28), 'channelTitle': 'BLACKPINK', 'categoryId': 'Music', 'trending_date': datetime.date(2020, 9, 3), 'views': 167334429, 'likes': 11474597, 'dislikes': 848974, 'comments': 2710901, 'thumbnail_link': 'https://i.ytimg.com/vi/vRXZj0DzXIA/default.jpg'}  ... displaying 10 of 9990 total bound parameter sets ...  {'country': 'IN', 'video_id': '5GRbUnw64W0', 'title': 'Panghat – Roohi | Rajkummar – Janhvi - Varun | Sachin- Jigar, Amitabh B | Asees K | Divya K|Mellow D', 'publishedAt': datetime.date(2021, 2, 22), 'channelTitle': 'Sony Music India', 'categoryId': 'Music', 'trending_date': datetime.date(2021, 2, 24), 'views': 18304492, 'likes': 311347, 'dislikes': 39693, 'comments': 11283, 'thumbnail_link': 'https://i.ytimg.com/vi/5GRbUnw64W0/default.jpg'}, {'country': 'IN', 'video_id': '5GRbUnw64W0', 'title': 'Panghat – Roohi | Rajkummar – Janhvi - Varun | Sachin- Jigar, Amitabh B | Asees K | Divya K|Mellow D', 'publishedAt': datetime.date(2021, 2, 22), 'channelTitle': 'Sony Music India', 'categoryId': 'Music', 'trending_date': datetime.date(2021, 2, 24), 'views': 18304492, 'likes': 311382, 'dislikes': 39702, 'comments': ...
# (Background on this error at: http://sqlalche.me/e/14/f405)

# %%
# dfh_main['categoryId'] = df_main['categoryId'].str.replace("29", "Nonprofits & Activism")
# dfh_main['categoryId'] = dfh_main['categoryId'].replace(["29"],"Nonprofits & Activism")


# df_main['categoryId'].value_counts()
# df_main['categoryId'].unique()
# dfh_main
# df_main = df_main(columns={})
# df_main['likes']

# df_main['publishedAt'].value_counts()

# %%
# Bar graph route
youtubeVids = df_main
country = "US"
metric = "likes"
youtubeVids['categoryId'] = youtubeVids['categoryId'].replace(["29"],"Nonprofits & Activism")
barGraph1Data = youtubeVids[youtubeVids["country"] == country]

barGraph1Data = barGraph1Data.groupby('categoryId').mean()
barGraph1Data = barGraph1Data[metric]
barGraph1Data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [5], line 2
#       1 # Bar graph route
# ----> 2 youtubeVids = df_main
#       3 country = "US"
#       4 metric = "likes"
#
# NameError: name 'df_main' is not defined

# %%
# Bargraph2 route
youtubeVids = df_main
country = "US"
metric = "likes"
catId = "Entertainment"

barGraph2Data = youtubeVids[youtubeVids["country"] == country]
barGraph2Data = barGraph2Data[barGraph2Data["categoryId"] == catId]
barGraph2Data = barGraph2Data.loc[:, ["views", "comments", "likes", "dislikes", "country", "categoryId"]]

metric_values = ["views", "comments", "likes", "dislikes"]
metricMaxValues = []
n = 0
for i in metric_values:
    step1_df = barGraph2Data.sort_values(by=i, ascending=False)
    step2_df = step1_df[i]
    step3 = step2_df.values.tolist()
    metricMaxValues.append(step3[0])
metricMaxValues

barGraph2_df = pd.DataFrame(
    {'Metric Values': metric_values,
     'Max Value': metricMaxValues
    })
barGraph2_df
# Out:
#   Metric Values  Max Value
# 0         views   60332012
# 1      comments     681063
# 2         likes    3871379
# 3      dislikes      76584

# %%
# table by category route
youtubeVids = df_main
country = "US"
metric = "likes"
category = "Entertainment"

# # Fix the 29 vs Non profits issue
youtubeVids['categoryId'] = youtubeVids['categoryId'].replace(["29"],"Nonprofits & Activism")

# # Sort dataframe by country & category
table_df = youtubeVids[youtubeVids["country"] == country]
table_df = table_df[table_df["categoryId"] == category]

# # Sort dataframe (largest to smallest) by metric
sorted_table_df = table_df.sort_values(by=metric, ascending=False)

# # Removing duplicate titles from dataframe
sorted_table_df = sorted_table_df.drop_duplicates(subset='title', keep="first")
sorted_table_df

# # Select top 10 from dataframe
top10List_df = sorted_table_df.nlargest(10, metric)

# # Select columns to keep
top10List_df = top10List_df[['categoryId', 'title', 'channelTitle', 'views', 'comments', 'trending_date', 'likes', 'dislikes', 'video_id' ]]
top10List_df
# Out:
#           categoryId                                              title  \
# 29541  Entertainment           Youtube Rewind 2020, Thank God It's Over
# 46572  Entertainment                      I Spent 50 Hours Buried Alive
# 31394  Entertainment                    I Bought Everything In 5 Stores
# 5397   Entertainment              BTS Performs Dynamite | 2020 MTV VMAs
# 37778  Entertainment                            LILI’s FILM [The Movie]
# 12196  Entertainment                                   Hi Me In 5 Years
# 26162  Entertainment  I Gave People $1,000,000 But ONLY 1 Minute To ...
# 33774  Entertainment                    I Ate $100,000 Golden Ice Cream
# 27594  Entertainment   I Opened A Restaurant That Pays You To Eat At It
# 2351   Entertainment             Last To Leave $800,000 Island Keeps It
#
#             channelTitle     views  comments trending_date    likes  dislikes  \
# 29541            MrBeast  33387176    295256    2021-01-10  3871379     53805
# 46572            MrBeast  60332012    195892    2021-04-05  3331049     44353
# 31394            MrBeast  31457820    177784    2021-01-19  2700253     18037
# 5397                 MTV  29442683    148096    2020-09-07  2577092     58524
# 37778  Lilifilm Official  24756742    253019    2021-02-20  2514021     21125
# 12196            MrBeast  21701884    175728    2020-10-11  2494869     10347
# 26162            MrBeast  33502455    138736    2020-12-23  2453839     24448
# 33774            MrBeast  33809019    131520    2021-01-31  2189731     27833
# 27594            MrBeast  31973364    678199    2020-12-31  2114647     20528
# 2351             MrBeast  31801966    201630    2020-08-23  2097381     35643
#
#           video_id
# 29541  PKtnafFtfEo
# 46572  9bqk6ZUsKyA
# 31394  5Fg9oZk-5uA
# 5397   zJCdkOpU90g
# 37778  vtRJZEHdu8M
# 12196  AKJfakEsgy0
# 26162  LeYsRMZFUq0
# 33774  C680oxL__ck
# 27594  dg2Ag3e8W-Q
# 2351   NkE0AMGzpJY
